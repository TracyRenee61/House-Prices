# %% [markdown]
# Problem Statement
#
# Ask a home buyer to describe their dream house, and they probably won't begin with the height of the basement ceiling or the proximity to an east-west railroad. But this playground competition's dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.
#
# With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home.
#
# Acknowledgments
#
# The Ames Housing dataset was compiled by Dean De Cock for use in data science education. It's an incredible alternative for data scientists looking for a modernized and expanded version of the often cited Boston Housing dataset.

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load files

# %%
#Load datasets
train=pd.read_csv("https://raw.githubusercontent.com/TracyRenee61/House-Prices/master/train.csv")
#Load datasets
test=pd.read_csv("https://raw.githubusercontent.com/TracyRenee61/House-Prices/master/test.csv")

# %%
train
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
test
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0     1461          20       RH  ...    2010        WD        Normal
# 1     1462          20       RL  ...    2010        WD        Normal
# 2     1463          60       RL  ...    2010        WD        Normal
# 3     1464          60       RL  ...    2010        WD        Normal
# 4     1465         120       RL  ...    2010        WD        Normal
# ...    ...         ...      ...  ...     ...       ...           ...
# 1454  2915         160       RM  ...    2006        WD        Normal
# 1455  2916         160       RM  ...    2006        WD       Abnorml
# 1456  2917          20       RL  ...    2006        WD       Abnorml
# 1457  2918          85       RL  ...    2006        WD        Normal
# 1458  2919          60       RL  ...    2006        WD        Normal
#
# [1459 rows x 80 columns]

# %% [markdown]
# Describe target

# %%
train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.displot(train['SalePrice']);

# %%
var = 'GrLivArea'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000), s=32);

# %%
var = 'TotalBsmtSF'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));

# %%
var = 'OverallQual'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(14, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %% [markdown]
# Heatmap

# %%
corrmat = train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %% [markdown]
# Feature selection

# %%
feature = ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea']

# %% [markdown]
# Append train and test

# %%
X_tot = train.drop('SalePrice', axis =1)
X_tot = X_tot.append(test)
X_tot
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0        1          60       RL  ...    2008        WD        Normal
# 1        2          20       RL  ...    2007        WD        Normal
# 2        3          60       RL  ...    2008        WD        Normal
# 3        4          70       RL  ...    2006        WD       Abnorml
# 4        5          60       RL  ...    2008        WD        Normal
# ...    ...         ...      ...  ...     ...       ...           ...
# 1454  2915         160       RM  ...    2006        WD        Normal
# 1455  2916         160       RM  ...    2006        WD       Abnorml
# 1456  2917          20       RL  ...    2006        WD       Abnorml
# 1457  2918          85       RL  ...    2006        WD        Normal
# 1458  2919          60       RL  ...    2006        WD        Normal
#
# [2919 rows x 80 columns]

# %% [markdown]
# Define X_tot and y

# %%
test_Id = test.Id

y = train.SalePrice
X_tot = X_tot[feature]

# %%
X_tot
# Out:
#       OverallQual  YearBuilt  ...  GarageCars  GarageArea
# 0               7       2003  ...         2.0       548.0
# 1               6       1976  ...         2.0       460.0
# 2               7       2001  ...         2.0       608.0
# 3               7       1915  ...         3.0       642.0
# 4               8       2000  ...         3.0       836.0
# ...           ...        ...  ...         ...         ...
# 1454            4       1970  ...         0.0         0.0
# 1455            4       1970  ...         1.0       286.0
# 1456            5       1960  ...         2.0       576.0
# 1457            5       1992  ...         0.0         0.0
# 1458            7       1993  ...         3.0       650.0
#
# [2919 rows x 11 columns]

# %% [markdown]
# Check for null values

# %%
X_tot.isnull().sum()
# Out:
# OverallQual      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea      23
# TotalBsmtSF      1
# 1stFlrSF         0
# GrLivArea        0
# FullBath         0
# TotRmsAbvGrd     0
# GarageCars       1
# GarageArea       1
# dtype: int64

# %% [markdown]
# Iterative Imputer

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imp = IterativeImputer(random_state=1)

X_tot = imp.fit_transform(X_tot)

# %% [markdown]
# Normalise X_tot

# %%
X_tot = (X_tot - X_tot.min()) / (X_tot.max() - X_tot.min())
X_tot
# Out:
# array([[1.14566285e-03, 3.27823241e-01, 3.27823241e-01, ...,
#         1.30932897e-03, 3.27332242e-04, 8.96890344e-02],
#        [9.81996727e-04, 3.23404255e-01, 3.23404255e-01, ...,
#         9.81996727e-04, 3.27332242e-04, 7.52864157e-02],
#        [1.14566285e-03, 3.27495908e-01, 3.27659574e-01, ...,
#         9.81996727e-04, 3.27332242e-04, 9.95090016e-02],
#        ...,
#        [8.18330606e-04, 3.20785597e-01, 3.26677578e-01, ...,
#         1.14566285e-03, 3.27332242e-04, 9.42716858e-02],
#        [8.18330606e-04, 3.26022913e-01, 3.26022913e-01, ...,
#         9.81996727e-04, 0.00000000e+00, 0.00000000e+00],
#        [1.14566285e-03, 3.26186579e-01, 3.26350245e-01, ...,
#         1.47299509e-03, 4.90998363e-04, 1.06382979e-01]])

# %% [markdown]
# Split X_tot for training and testing

# %%
row = len(train)

X_Train = X_tot[: row]
X_test = X_tot[row :]

# %%
X_Train.shape, X_test.shape
# Out:
# ((1460, 11), (1459, 11))

# %% [markdown]
# Split X_Train for training and validation

# %%
from sklearn.model_selection import train_test_split

# Split into validation and training data
X_train, X_val, y_train, y_val = train_test_split(X_Train, y, test_size=0.05, random_state=1)
X_train.shape, X_val.shape, y_train.shape,y_val.shape, X_test.shape
# Out:
# ((1387, 11), (73, 11), (1387,), (73,), (1459, 11))

# %% [markdown]
# Select Model

# %%
from sklearn import linear_model as lm

model = lm.Lasso(max_iter=10000, random_state=1, alpha=.1).fit(X_train, y_train)
print(model.score(X_train, y_train))
# Out:
# 0.771526806853013

# %% [markdown]
# Predict on validation set

# %%
y_pred = model.predict(X_val)
y_pred = y_pred.astype(int)
print(model.score(X_val, y_val))
# Out:
# 0.8675293336739552

# %%
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error(y_val, y_pred, squared=False)
rmse
# Out:
# 30304.90124403904

# %%
df=pd.DataFrame({'Actual': y_val, 'Predicted':y_pred})
df
# Out:
#       Actual  Predicted
# 258   231500     223161
# 267   179500     167406
# 288   122000     106641
# 649    84500      55131
# 1233  142000     142784
# ...      ...        ...
# 1434  160000     140359
# 1053  144500     166030
# 1173  200500     221730
# 48    113000      99166
# 321   354000     301011
#
# [73 rows x 2 columns]

# %% [markdown]
# Graphics

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_val, y_pred, c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(y_pred), max(y_val))
p2 = min(min(y_pred), min(y_val))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('Actual Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
plt.plot(df.Actual)
plt.plot(df.Predicted, 'o')
plt.show()

# %% [markdown]
# Predict on test set and submit

# %%
final_labels = model.predict(X_test)

final_labels[final_labels < 0] = 0
final_labels = final_labels.astype(int)
final_labels
# Out:
# array([113158, 157385, 168384, ..., 153321, 110903, 235357])

# %%
final_result = pd.DataFrame({'Id': test_Id, 'SalePrice': final_labels})

# %%
final_result.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!

# %%
#upload submission
submission = pd.read_csv("submission.csv")
submission
# Out:
#         Id  SalePrice
# 0     1461     113158
# 1     1462     157385
# 2     1463     168384
# 3     1464     185905
# 4     1465     215631
# ...    ...        ...
# 1454  2915      73716
# 1455  2916      86938
# 1456  2917     153321
# 1457  2918     110903
# 1458  2919     235357
#
# [1459 rows x 2 columns]
